# %% [markdown]
# <a href="https://colab.research.google.com/github/ruthetum/salmon/blob/master/infoYouTube.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup
# !pip install pytube3
from pytube import YouTube
# Out:
# Collecting pytube3
#   Downloading https://files.pythonhosted.org/packages/de/86/198092763646eac7abd2063192ab44ea44ad8fd6d6f3ad8586b38afcd52a/pytube3-9.6.4-py3-none-any.whl
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.6/dist-packages (from pytube3) (3.6.6)
# Installing collected packages: pytube3
# Successfully installed pytube3-9.6.4

# %%
video_url = 'https://www.youtube.com/watch?v=2Cjpth9ljMI&list=PLqylIKbCwYVwxiJi-48Lklo3uxqOHNDyY&index=3U'
video = YouTube(video_url)

# %%
print("[영상 제목]", video.title)  # 영상제목
print("[영상 게시자]", video.author) # 영상 게시자
print("[조회수]", video.views)
print("[평균평점]", video.rating) # 평균 평점
print("[영상길이(초)]", video.length)
print("[연령제한여부]", video.age_restricted)
print("[영상 설명]", video.description) # 영상 설명
print("[썸네일URL]", video.thumbnail_url) # 썸네일 url 주소
# Out:
# [영상 제목] 5학년 2학기 사회(역사) 2-(3)대한민국 정부의 수립과 6.25 전쟁 1차시 8.15 광복의 과정을 알아봅시다.(옥정초등학교 5학년 5반)
# [영상 게시자] 사성진
# [조회수] 184
# [평균평점] 5.0
# [영상길이(초)] 439
# [연령제한여부] False
# [영상 설명]
# [썸네일URL] https://i.ytimg.com/vi/2Cjpth9ljMI/maxresdefault.jpg

# %%
# video.streams.all()

# 전송 포맷 중 첫번째 선택
# stream = video.streams.all()[0]
# stream
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">

# 음성만 선택시
# video.streams.filter(only_audio = True).all()

# mp4
# video.streams.filter(file_extension = 'mp4').all( )

# %%
# 선택
# stream = video.streams.filter(file_extension = 'mp4').all( )[0]
# stream
# <Stream: itag="18" mime_type="video/mp4" res="360p" fps="30fps" vcodec="avc1.42001E" acodec="mp4a.40.2" progressive="True" type="video">

# 영상 다운로드
# stream.download()

# 파일 이름 지정 
## 폴더지정 가능
# stream.download(output_path='test', filename = 'KOBE', filename_prefix= 'R.I.P_')

# %%
video.captions.all()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function all (This object can be treated as a dictionary).
#   """Entry point for launching an IPython kernel.
# [<Caption lang="Korean (auto-generated)" code="ko">]

# %%
caption = video.captions.get_by_language_code('ko')
if caption == None:
    caption = video.captions.all()[0]

# 자막 xml 포멧 
caption.xml_captions
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated function get_by_language_code (This object can be treated as a dictionary, i.e. captions['en']).
#   """Entry point for launching an IPython kernel.
# '<?xml version="1.0" encoding="utf-8" ?><transcript><text start="0" dur="9.45">자 오늘은 파리도 왕복에 과정을 알아보도록 하겠습니다</text><text start="5.43" dur="10.709">이런 8월 15일은 광복절 이죠</text><text start="9.45" dur="9.229">광복절은 1945년 우리나라가 일본으로부터 광복 된 것을 기념하는</text><text start="16.139" dur="9.95">날인데요</text><text start="18.679" dur="10.44">저 광복이 나은 무슨 의미일까요 광복이 랑 다른 나라의 뺏긴 땅과 주권을</text><text start="26.089" dur="9.301">토로 찾는 것을 의미합니다</text><text start="29.119" dur="9.991">신문에 그날이 오면 이라는 씨를 보면 그 날이 오면 그 날이 오면</text><text start="35.39" dur="11.16">삼각산 2 일어나 도 덩실 춤이라도 추고</text><text start="39.11" dur="9.409">한강물이 뒤집혀 용주 cm 의 그날이 오면 이렇게 좋은 날이 온다면 그</text><text start="46.55" dur="7.829">나는 과연 어떤 날일까요</text><text start="48.519" dur="8.92">3일 운동에 참여했던 당시 시인 의 간격을 되 살리면서</text><text start="54.379" dur="6.201">광복 냉 조국의 그냥</text><text start="57.439" dur="3.141">즉 일본으로부터</text><text start="63.059" dur="2.511">나 네</text><text start="65.969" dur="9.69">되찾은</text><text start="68.49" dur="12.83">다리 오면 얼마가 좋을까 라는 생각으로 센 시입니다</text><text start="75.659" dur="11.75">그러면 우리 나라가 어떻게 일본으로부터 다시 나라를 되찾게 되었는지</text><text start="81.32" dur="6.089">오늘은 그 과정을 한번 살펴보도록 하겠습니다</text><text start="87.64" dur="10.53">자 제 2 2차 세계 대전 이라고 해서 1939년부터 1945년까지</text><text start="93.55" dur="10.38">일어난 대규모 세계 전쟁 2 있었어요</text><text start="98.17" dur="12.12">인류 역사상 가장 많 피해를 남긴 정쟁 내길 이탈리아 일본 등의 주 축구</text><text start="103.93" dur="8.93">꽈 영국 프랑스 미국 소년 등의 연합국 사이에 벌어진 세계 규모의</text><text start="110.29" dur="2.57">전쟁이었습니다</text><text start="112.9" dur="10.71">자 당시 일부 문화 싸우던 연합국은</text><text start="117.25" dur="9.9">국내외 독립운동가들의 끊임없는 노력 때 상하이 의 임시정부를 만들어서</text><text start="123.61" dur="10.14">독립운동을 전개하고 한국광복군 의</text><text start="127.15" dur="10.8">조직해서 일종의 저항 것들 이런 것들을 인정하면서 여러 회담에서</text><text start="133.75" dur="7.14">뭐 카이로 선언이 나 부츠 다음에 나오미는 연어의 담 내서</text><text start="137.95" dur="9.09">우리나라의 독립을 약속했습니다</text><text start="140.89" dur="12.42">대표 졸 카이로 선언에서 는 미국 영국 중국의 새 나라가 한국민 2</text><text start="147.04" dur="12">노예 상태에 있다는 것을 유념해서 앞으로 적절한 절차를 거쳐서 한국의</text><text start="153.31" dur="9.87">자유업 독립 후에 줄 것을 결의안 나 뭐 이런 이야기 됐구요</text><text start="159.04" dur="11.419">이런 상황에서 연합군이 전쟁에서 승리하고</text><text start="163.18" dur="9.81">일본이 무조건 한국성 을 하면서 우리나라는 1945년 8월 15일에</text><text start="170.459" dur="6.851">광복을 맞이합니다</text><text start="172.99" dur="7.38">즉 일제 식민 지배로 부터 벗어나서</text><text start="177.31" dur="8.01">독립을 하게 되었다 는 의미죠</text><text start="180.37" dur="11.1">취해서 말했던 그 날이 드디어 오게 된것입니다</text><text start="185.32" dur="10.98">자 이전부터 독립 운동가들은 광복 이후의 즉 일본으로부터 나라를 되찾은</text><text start="191.47" dur="12.51">후에 어떤 나라를 만들 것인가 고민을 했습니다</text><text start="196.3" dur="10.05">자 대한민국 임시정부는 건국의 원칙을 발표 하게 됐고 국내에서도 건국을</text><text start="203.98" dur="8.509">준비 하는 단체가 만들어줘서</text><text start="206.35" dur="6.139">나라의 질서를 유지하고자 아니 노력을 했습니다</text><text start="214.55" dur="9.03">대한민국 임시정부의 공부 권 치근 조소 아니라는 사람의 삶 균주 의</text><text start="220.19" dur="8.91">나는걸 바탕을 만들어 졌는데요</text><text start="223.58" dur="8.64">저희 3 균주 이란 3가지 분야에서 차별이 없이 동등 해야 줘야 된다</text><text start="229.1" dur="8.61">평등해야 한다 사람과 사람</text><text start="232.22" dur="12.69">민족과 민족 나라와 나라 사이에 서로 평등하게 걸릴 누려야 한다는 것으로</text><text start="237.71" dur="9.09">뭐 지금 아군 지금도 볼수 있는 선거를 할 때 누구나 차별 없이 한 표를</text><text start="244.91" dur="8.04">던진다 라든가</text><text start="246.8" dur="10.28">모든 악 모든 아이들이 공짜로 학교를 다니면서 배움의 기회를 얻어야 된다</text><text start="252.95" dur="4.13">이런 것들이 포함되어 있었죠</text><text start="257.79" dur="8.52">광복 수식이 전에 지자 중국 일본 미국 등 다른 남의 머물던 동포들 독</text><text start="263.669" dur="8.281">국내로 돌아와 씁니다</text><text start="266.31" dur="6.96">자 또한 해외에서 활동하던 많은 독립운동 만들 도 그리던 고국으로 돌아</text><text start="271.95" dur="6.54">왔는데요</text><text start="273.27" dur="8.31">자 이 사진은 대한민국 음식 정도 의 주요 인물들이 귀국하기 전에 충칭</text><text start="278.49" dur="8.37">해서 기념으로 찍은 사진입니다</text><text start="281.58" dur="9">방법 을 맞아 999 에 돌아오는 독립운동가들의 마음 어땠을까요</text><text start="286.86" dur="11.37">드디어 나라를 되찾았다는 기쁨도 있었겠지만</text><text start="290.58" dur="14.1">우리 손으로 직접 관공을 하지 못해 아쉬움도 남아 있었다고 합니다</text>< ...

# %%
# 자막 srt 포멧
print(caption.generate_srt_captions())

# 자막 다운받기: download("파일명")
# caption.download(video.title )
# Out:
# 1
# 00:00:00,000 --> 00:00:09,450
# 자 오늘은 파리도 왕복에 과정을 알아보도록 하겠습니다
#
# 2
# 00:00:05,430 --> 00:00:16,139
# 이런 8월 15일은 광복절 이죠
#
# 3
# 00:00:09,450 --> 00:00:18,679
# 광복절은 1945년 우리나라가 일본으로부터 광복 된 것을 기념하는
#
# 4
# 00:00:16,139 --> 00:00:26,089
# 날인데요
#
# 5
# 00:00:18,679 --> 00:00:29,119
# 저 광복이 나은 무슨 의미일까요 광복이 랑 다른 나라의 뺏긴 땅과 주권을
#
# 6
# 00:00:26,089 --> 00:00:35,390
# 토로 찾는 것을 의미합니다
#
# 7
# 00:00:29,119 --> 00:00:39,110
# 신문에 그날이 오면 이라는 씨를 보면 그 날이 오면 그 날이 오면
#
# 8
# 00:00:35,390 --> 00:00:46,550
# 삼각산 2 일어나 도 덩실 춤이라도 추고
#
# 9
# 00:00:39,110 --> 00:00:48,519
# 한강물이 뒤집혀 용주 cm 의 그날이 오면 이렇게 좋은 날이 온다면 그
#
# 10
# 00:00:46,550 --> 00:00:54,379
# 나는 과연 어떤 날일까요
#
# 11
# 00:00:48,519 --> 00:00:57,439
# 3일 운동에 참여했던 당시 시인 의 간격을 되 살리면서
#
# 12
# 00:00:54,379 --> 00:01:00,580
# 광복 냉 조국의 그냥
#
# 13
# 00:00:57,439 --> 00:01:00,580
# 즉 일본으로부터
#
# 14
# 00:01:03,059 --> 00:01:05,570
# 나 네
#
# 15
# 00:01:05,969 --> 00:01:15,659
# 되찾은
#
# 16
# 00:01:08,490 --> 00:01:21,320
# 다리 오면 얼마가 좋을까 라는 생각으로 센 시입니다
#
# 17
# 00:01:15,659 --> 00:01:27,409
# 그러면 우리 나라가 어떻게 일본으로부터 다시 나라를 되찾게 되었는지
#
# 18
# 00:01:21,320 --> 00:01:27,409
# 오늘은 그 과정을 한번 살펴보도록 하겠습니다
#
# 19
# 00:01:27,640 --> 00:01:38,170
# 자 제 2 2차 세계 대전 이라고 해서 1939년부터 1945년까지
#
# 20
# 00:01:33,550 --> 00:01:43,930
# 일어난 대규모 세계 전쟁 2 있었어요
#
# 21
# 00:01:38,170 --> 00:01:50,290
# 인류 역사상 가장 많 피해를 남긴 정쟁 내길 이탈리아 일본 등의 주 축구
#
# 22
# 00:01:43,930 --> 00:01:52,860
# 꽈 영국 프랑스 미국 소년 등의 연합국 사이에 벌어진 세계 규모의
#
# 23
# 00:01:50,290 --> 00:01:52,860
# 전쟁이었습니다
#
# 24
# 00:01:52,900 --> 00:02:03,610
# 자 당시 일부 문화 싸우던 연합국은
#
# 25
# 00:01:57,250 --> 00:02:07,150
# 국내외 독립운동가들의 끊임없는 노력 때 상하이 의 임시정부를 만들어서
#
# 26
# 00:02:03,610 --> 00:02:13,750
# 독립운동을 전개하고 한국광복군 의
#
# 27
# 00:02:07,150 --> 00:02:17,950
# 조직해서 일종의 저항 것들 이런 것들을 인정하면서 여러 회담에서
#
# 28
# 00:02:13,750 --> 00:02:20,890
# 뭐 카이로 선언이 나 부츠 다음에 나오미는 연어의 담 내서
#
# 29
# 00:02:17,950 --> 00:02:27,040
# 우리나라의 독립을 약속했습니다
#
# 30
# 00:02:20,890 --> 00:02:33,310
# 대표 졸 카이로 선언에서 는 미국 영국 중국의 새 나라가 한국민 2
#
# 31
# 00:02:27,040 --> 00:02:39,040
# 노예 상태에 있다는 것을 유념해서 앞으로 적절한 절차를 거쳐서 한국의
#
# 32
# 00:02:33,310 --> 00:02:43,180
# 자유업 독립 후에 줄 것을 결의안 나 뭐 이런 이야기 됐구요
#
# 33
# 00:02:39,040 --> 00:02:50,459
# 이런 상황에서 연합군이 전쟁에서 승리하고
#
# 34
# 00:02:43,180 --> 00:02:52,990
# 일본이 무조건 한국성 을 하면서 우리나라는 1945년 8월 15일에
#
# 35
# 00:02:50,459 --> 00:02:57,310
# 광복을 맞이합니다
#
# 36
# 00:02:52,990 --> 00:03:00,370
# 즉 일제 식민 지배로 부터 벗어나서
#
# 37
# 00:02:57,310 --> 00:03:05,320
# 독립을 하게 되었다 는 의미죠
#
# 38
# 00:03:00,370 --> 00:03:11,470
# 취해서 말했던 그 날이 드디어 오게 된것입니다
#
# 39
# 00:03:05,320 --> 00:03:16,300
# 자 이전부터 독립 운동가들은 광복 이후의 즉 일본으로부터 나라를 되찾은
#
# 40
# 00:03:11,470 --> 00:03:23,980
# 후에 어떤 나라를 만들 것인가 고민을 했습니다
#
# 41
# 00:03:16,300 --> 00:03:26,350
# 자 대한민국 임시정부는 건국의 원칙을 발표 하게 됐고 국내에서도 건국을
#
# 42
# 00:03:23,980 --> 00:03:32,489
# 준비 하는 단체가 만들어줘서
#
# 43
# 00:03:26,350 --> 00:03:32,489
# 나라의 질서를 유지하고자 아니 노력을 했습니다
#
# 44
# 00:03:34,550 --> 00:03:43,580
# 대한민국 임시정부의 공부 권 치근 조소 아니라는 사람의 삶 균주 의
#
# 45
# 00:03:40,190 --> 00:03:49,100
# 나는걸 바탕을 만들어 졌는데요
#
# 46
# 00:03:43,580 --> 00:03:52,220
# 저희 3 균주 이란 3가지 분야에서 차별이 없이 동등 해야 줘야 된다
#
# 47
# 00:03:49,100 --> 00:03:57,710
# 평등해야 한다 사람과 사람
#
# 48
# 00:03:52,220 --> 00:04:04,910
# 민족과 민족 나라와 나라 사이에 서로 평등하게 걸릴 누려야 한다는 것으로
#
# 49
# 00:03:57,710 --> 00:04:06,800
# 뭐 지금 아군 지금도 볼수 있는 선거를 할 때 누구나 차별 없이 한 표를
#
# 50
# 00:04:04,910 --> 00:04:12,950
# 던진다 라든가
#
# 51
# 00:04:06,800 --> 00:04:17,080
# 모든 악 모든 아이들이 공짜로 학교를 다니면서 배움의 기회를 얻어야 된다
#
# 52
# 00:04:12,950 --> 00:04:17,080
# 이런 것들이 포함되어 있었죠
#
# 53
# 00:04:17,790 --> 00:04:26,310
# 광복 수식이 전에 지자 중국 일본 미국 등 다른 남의 머물던 동포들 독
#
# 54
# 00:04:23,669 --> 00:04:31,950
# 국내로 돌아와 씁니다
#
# 55
# 00:04:26,310 --> 00:04:33,270
# 자 또한 해외에서 활동하던 많은 독립운동 만들 도 그리던 고국으로 돌아
#
# 56
# 00:04:31,950 --> 00:04:38,490
# 왔는데요
#
# 57
# 00:04:33,270 --> 00:04:41,580
# 자 이 사진은 대한민국 음식 정도 의 주요 인물들이 귀국하기 전에 충칭
#
# 58
# 00:04:38,490 --> 00:04:46,860
# 해서 기념으로 찍은 사진입니다
#
# 59
# 00:04:41,580 --> 00:04:50,580
# 방법 을 맞아 999 에 돌아오는 독립운동가들의 마음 어땠을까요
#
# 60
# 00:04:46,860 --> 00:04:58,230
# 드디어 나라를 되찾았다는 기쁨도 있었겠지만
#
# 61
# 00:04:50,580 --> 00:05:04,680
# 우리 손으로 직접 관공을 하지 못해 아쉬움도 남아 있었다고 합니다
#
# 62
# 00:04:58,230 --> 00:05:11,480
# 당시 한국 광복군 국내 진입이 결전의 날을 9월로 준비하고 있었는데 그것
#
# 63
# 00:05:04,680 --> 00:05:11,480
# 조금 일찍 45명 8월 15일에 일본이 항복을 하면서
#
# 64
# 00:05:12,720 --> 00:05:23,040
# 천신만고 룩 수년간에 를 써서 참전할 준비한 것들이 모두 헌 일이 되었다
#
# 65
# 00:05:19,080 --> 00:05:29,250
# 라는 안타까움 아쉬움을 보이기도 했죠
#
# 66
# 00:05:23,040 --> 00:05:35,600
# 이런 기쁨과 아쉬움 속에 10월에는 이승만이 귀국해 있고 11월에는
#
# 67
# 00:05:29,250 --> 00:05:35,600
# 김구를 비롯한 대한민국 임시 정부의 주요 인물들이 귀국을 했습니다
#
# 68
# 00:05:35,770 --> 00:05:43,270
# 민족 지도자들은 일본을 물리치고 독립을 이루자는 같은 목적을 가지고 힘을
#
# 69
# 00:05:41,920 --> 00:05:48,760
# 모았지만
#
# 70
# 00:05:43,270 --> 00:05:50,500
# 독립된 후에는 각자의 생각에 따라서 여러 가지 정치적 경제적 혼란이
#
# 71
# 00:05:48,760 --> 00:05:56,160
# 있기도 했어요
#
# 72
# 00:05:50,500 --> 00:06:01,540
# 하지만 우리 민족은 독립된 국가를 만들고자 다양한 노력을 기울였습니다
#
# 73
# 00:05:56,160 --> 00:06:06,760
# 광복을 맞이에 만세를 부르는 사람들의 모습 자 일본에서 0 으로 돌아온
#
# 74
# 00:06:01,540 --> 00:06:09,910
# 사람들의 모습과 여자 근로정신대 로 유분에 끌려갔던 소녀들이 교육학
#
# 75
# 00:06:06,760 --> 00:06:16,979
# 이전의 모습이 담긴 사진을 보면서
#
# 76
# 00:06:09,910 --> 00:06:21,919
# 자 일본이 항복하고 우리나라가 광복을 맞은 나네 사람들이 마음이 어땠을지
#
# 77
# 00:06:16,979 --> 00:06:21,919
# 한번 생각해 보는 것도 좋을 것 같구요
#
# 78
# 00:06:22,560 --> 00:06:34,889
# 저택과 서 130 육적 탐구 활동에는 광복 이후의 어린이들이 학교 생활이
#
# 79
# 00:06:28,590 --> 00:06:41,430
# 어떻게 달라졌는지 살펴볼 수 있는 글과 사진도 있습니다
#
# 80
# 00:06:34,889 --> 00:06:46,849
# 이런 글과 사진을 보면서 여러분이 광복 당시 국민 학생이라고 생각을 하고
#
# 81
# 00:06:41,430 --> 00:06:49,800
# 광복 후에 달라진 생활 모습을 일기로 1 먼 써보는 것도 실제 수업시간에
#
# 82
# 00:06:46,849 --> 00:06:56,099
# 진행해 볼 건데요
#
# 83
# 00:06:49,800 --> 00:07:02,669
# 자 여기서 일본인 교사들이 일본으로 돌아갔고 우리나라 선생님에게 우리말로
#
# 84
# 00:06:56,099 --> 00:07:05,250
# 펼수 있게 된거 그리고 일본 왕에게 충성을 다하겠다는 황국 신민 성사를
#
# 85
# 00:07:02,669 --> 00:07:09,560
# 을 번 외울 필요 없었던 것
#
# 86
# 00:07:05,250 --> 00:07:15,000
# 교실에서 일본 과 가 되는 것들이 사라지고 일본어를 사용하지 않게 된것
#
# 87
# 00:07:09,560 --> 00:07:18,229
# 이런 것들을 여러분의 한번 다시 살펴보면서 생활 모습 1
#
# 88
# 00:07:15,000 --> 00:07:18,229
# 얘기로 써보겠습니다
